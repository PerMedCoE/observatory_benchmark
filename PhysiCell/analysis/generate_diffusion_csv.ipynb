# %%
import sys,os,re,argparse,glob
import pandas as pd
from scipy.io import loadmat
from pathlib import Path
import matplotlib.pyplot as plt

# %%
csv_out="/summary.csv"

# %%
folders = ["../results/many_diffusion_cell_sink","../results/single_diffusion_cell_sink","../results/many_diffusion_voxel_sink","../results/single_diffusion_voxel_sink"]

# %%
for output_folder in folders:
# generate csv of all voxels and their diffusion in each timestep
    files = Path(output_folder).glob('*output*_microenvironment*.mat')
    print(output_folder)
    step = 0.01
    df_cell = pd.DataFrame(columns = ['x','y','z','vol','diff'])
    i = 0
    for file in sorted(files):
        file
        mat = loadmat(file)
        mat = mat["multiscale_microenvironment"]
        steps = [step*i] * mat.shape[1]
        df_mat = pd.DataFrame(mat.transpose(),columns = ['x','y','z','vol','diff'])
        df_mat["timestep"] = steps
        df_cell= pd.concat([df_cell,df_mat])
        i= i + 1
    df_cell.to_csv(output_folder+csv_out)
# Out:
# ../results/many_diffusion_cell_sink
# /tmp/ipykernel_35063/3101543707.py:15: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_cell= pd.concat([df_cell,df_mat])
# ../results/single_diffusion_cell_sink
# /tmp/ipykernel_35063/3101543707.py:15: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_cell= pd.concat([df_cell,df_mat])
# ../results/many_diffusion_voxel_sink
# /tmp/ipykernel_35063/3101543707.py:15: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_cell= pd.concat([df_cell,df_mat])
# ../results/single_diffusion_voxel_sink
# /tmp/ipykernel_35063/3101543707.py:15: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_cell= pd.concat([df_cell,df_mat])

# %%
df_cell
# Out:
#        x     y     z     vol    diff  timestep
# 0  -20.0 -20.0 -20.0  8000.0     0.0       0.0
# 1    0.0 -20.0 -20.0  8000.0     0.0       0.0
# 2   20.0 -20.0 -20.0  8000.0     0.0       0.0
# 3  -20.0   0.0 -20.0  8000.0     0.0       0.0
# 4    0.0   0.0 -20.0  8000.0     0.0       0.0
# ..   ...   ...   ...     ...     ...       ...
# 22   0.0   0.0  20.0  8000.0  6022.0      10.0
# 23  20.0   0.0  20.0  8000.0  6022.0      10.0
# 24 -20.0  20.0  20.0  8000.0  6022.0      10.0
# 25   0.0  20.0  20.0  8000.0  6022.0      10.0
# 26  20.0  20.0  20.0  8000.0  6022.0      10.0
#
# [27027 rows x 6 columns]
