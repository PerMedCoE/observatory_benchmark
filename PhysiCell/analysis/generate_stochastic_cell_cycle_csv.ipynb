# %%
import pandas as pd
from scipy.io import loadmat
from pathlib import Path

import numpy as np

# %%
output_folder = "../results/custom_stochastic_cell_cycle/"

# %%
df_cell = pd.DataFrame(columns=['id', 'total_volume', 'current_phase', 'dt'])

# Set time interval
interval = 30.0
i = 0

# Get list of .mat files matching pattern
files = sorted(Path(output_folder).glob('*output*_cells.mat'))

# Loop through files
for file in files:
    mat = loadmat(file)
    # Extract the required rows from 'cells' array
    cell_data = mat['cells'][[0, 4, 7,8]]
    # Transpose and create a DataFrame
    df_mat = pd.DataFrame(cell_data.T, columns=['id', 'total_volume', 'current_phase',"elapsed_time_in_phase"])
    # Add timepoint
    df_mat['dt'] = round(i * interval, 1)
    # Append to main DataFrame
    df_cell = pd.concat([df_cell, df_mat], ignore_index=True)
    i += 1

# Sort by dt and reset index
# df_cell = df_cell.sort_values(by='dt').reset_index(drop=True)

# Save to CSV
df_cell.to_csv(Path(output_folder) / "cell_volumes.csv", index=False)
df_cell
# Out:
# /tmp/ipykernel_40963/2437579220.py:20: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_cell = pd.concat([df_cell, df_mat], ignore_index=True)
#       id  total_volume  current_phase      dt  elapsed_time_in_phase
# 0    0.0    523.600000            4.0     0.0                    0.0
# 1    0.0    523.600000            4.0    30.0                   30.0
# 2    0.0    523.600000            4.0    60.0                   60.0
# 3    0.0    523.600000            4.0    90.0                   90.0
# 4    0.0    523.600000            4.0   120.0                  120.0
# ..   ...           ...            ...     ...                    ...
# 204  4.0    913.217637           10.0  2850.0                  360.0
# 205  0.0    893.039510           10.0  2880.0                  330.0
# 206  2.0    909.505110           10.0  2880.0                  354.0
# 207  3.0    948.257180           10.0  2880.0                  426.0
# 208  4.0    930.653005           10.0  2880.0                  390.0
#
# [209 rows x 5 columns]
