# %%
import pandas as pd
from scipy.io import loadmat
from pathlib import Path

import numpy as np

# %%
output_folder = "../results/stochastic_cell_cycle/"

# %%
df_cell = pd.DataFrame(columns=['id', 'x', 'y', 'z', 'total_volume', 'current_phase', 'dt'])

# Set time interval
interval = 30.0
i = 0

# Get list of .mat files matching pattern
files = sorted(Path(output_folder).glob('*output*_cells.mat'))

# Loop through files
for file in files:
    mat = loadmat(file)
    # Extract the required rows from 'cells' array
    cell_data = mat['cells'][[0, 1, 2, 3, 4, 7]]
    # Transpose and create a DataFrame
    df_mat = pd.DataFrame(cell_data.T, columns=['id', 'x', 'y', 'z', 'total_volume', 'current_phase'])
    # Add timepoint
    df_mat['dt'] = round(i * interval, 1)
    # Append to main DataFrame
    df_cell = pd.concat([df_cell, df_mat], ignore_index=True)
    i += 1

# Sort by dt and reset index
df_cell = df_cell.sort_values(by='dt').reset_index(drop=True)

# Save to CSV
df_cell.to_csv(Path(output_folder) / "cell_volumes.csv", index=False)
df_cell
# Out:
# /tmp/ipykernel_17633/3237458763.py:20: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_cell = pd.concat([df_cell, df_mat], ignore_index=True)
#        id         x         y         z  total_volume  current_phase      dt
# 0     0.0  0.000000  0.000000  0.000000    523.600000            4.0     0.0
# 1     0.0  0.000000  0.000000  0.000000    523.600000            4.0    30.0
# 2     0.0  0.000000  0.000000  0.000000    523.600000            4.0    60.0
# 3     0.0  0.000000  0.000000  0.000000    523.600000           10.0    90.0
# 4     0.0  0.000000  0.000000  0.000000    548.770598           10.0   120.0
# ..    ...       ...       ...       ...           ...            ...     ...
# 359   2.0 -7.223212 -4.603744 -0.858339    513.369115            4.0  2880.0
# 360   0.0  9.720622 -4.832263  0.151310    901.593933           10.0  2880.0
# 361   9.0 -6.461507  0.928968 -9.185060    723.570967           10.0  2880.0
# 362  10.0 -7.358038  0.455180  8.081767    468.424903            4.0  2880.0
# 363  11.0  2.982994  0.368706 -5.868083    514.188948            4.0  2880.0
#
# [364 rows x 7 columns]
